# %% [markdown]
# <a href="https://colab.research.google.com/github/hugoplm/bitcoin-candlestick/blob/main/5_Exercicio_DeepLearning_MNIST/DL_MNIST_Modelo4_Hugo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Carregando os Dados

# %% [markdown]
# Informações do Dataset
#
# This is a dataset of 60,000 28x28 grayscale images of the 10 digits, along with a test set of 10,000 images
#
#
# - Returns
#
# Tuple of NumPy arrays: (x_train, y_train), (x_test, y_test).

# %%
from tensorflow import keras
import cv2
import numpy as np
import matplotlib.pyplot as plt
from random import randint
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
(X_train_raw, y_train_raw), (X_test_raw, y_test_raw) = keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# 26435584/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
print("X_train: ", X_train_raw.shape)
print("y_train: ", y_train_raw.shape)
print("X_test:  ", X_test_raw.shape)
print("y_test:  ", y_test_raw.shape)
# Out:
# X_train:  (60000, 28, 28)
# y_train:  (60000,)
# X_test:   (10000, 28, 28)
# y_test:   (10000,)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
f, ax = plt.subplots(5,5)
f.subplots_adjust(0,0,1.5,1.5)
for i in range(0,5,1):
  for j in range(0,5,1):
    rnd_number = randint(0,len(X_train_raw))
    ax[i,j].imshow(X_train_raw[rnd_number], cmap=plt.cm.binary)
    ax[i,j].set_title(class_names[y_train_raw[rnd_number]])
    ax[i,j].axis('off')

# %% [markdown]
# # Pré-processamento dos Dados

# %%
X_train, X_val, y_train, y_val = train_test_split(
     X_train_raw, y_train_raw, stratify=y_train_raw, test_size=0.33, random_state=42)

# %%
hot = OneHotEncoder()
y_train = hot.fit_transform(y_train.reshape(-1,1)).toarray()
y_val = hot.transform(y_val.reshape(-1,1)).toarray()

# %%
X_train = X_train / 255
X_val = X_val / 255

# %%
print(X_train.shape)
print(X_val.shape)
print(y_train.shape)
print(y_val.shape)
# Out:
# (40200, 28, 28)
# (19800, 28, 28)
# (40200, 10)
# (19800, 10)

# %% [markdown]
# Distribuição das Classes

# %%
import seaborn as sns
sns.countplot(y_train_raw);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #Modelo Deep Learning

# %% [markdown]
# ## Carregando as Bibliotecas

# %%
from tensorflow.python.keras.layers import Input, Dense, Activation, Dropout, Flatten
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.callbacks import EarlyStopping

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Modelo 4
#
# Inclusão de Dropout

# %% [markdown]
# ### Definição da Arquitetura

# %%
rede = Sequential()

rede.add(Flatten())
rede.add(Dense(25,  input_dim = X_train.shape[1]*X_train.shape[2]))
rede.add(Activation('relu'))
rede.add(Dense(64))
rede.add(Activation('relu'))
rede.add(Dropout(0.5))
rede.add(Dense(64))
rede.add(Activation('relu'))
rede.add(Dense(128))
rede.add(Activation('relu'))
rede.add(Dropout(0.5))
rede.add(Dense(128))
rede.add(Activation('relu'))
rede.add(Dense(10))
rede.add(Activation('softmax'))

# %%
es = EarlyStopping(monitor = 'val_loss', 
                   min_delta = 0.001, 
                   patience = 10, 
                   verbose = 1, 
                   mode = 'auto')

# %%
rede.compile(loss = 'categorical_crossentropy', 
              optimizer = 'Adam', 
              metrics=['accuracy'])

# %% [markdown]
# ### Treinamento do Modelo

# %%
hist = rede.fit(X_train, 
                y_train, 
                epochs = 50,
                batch_size=50,
                verbose = 1,
                validation_data = (X_val, y_val),
                callbacks = [es])
# Out:
# Epoch 1/50
# 804/804 [==============================] - 13s 9ms/step - loss: 0.9135 - accuracy: 0.6462 - val_loss: 0.5473 - val_accuracy: 0.8046
# Epoch 2/50
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5881 - accuracy: 0.7909 - val_loss: 0.4861 - val_accuracy: 0.8260
# Epoch 3/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5285 - accuracy: 0.8158 - val_loss: 0.4337 - val_accuracy: 0.8469
# Epoch 4/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4924 - accuracy: 0.8287 - val_loss: 0.4497 - val_accuracy: 0.8466
# Epoch 5/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4642 - accuracy: 0.8387 - val_loss: 0.4161 - val_accuracy: 0.8584
# Epoch 6/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4447 - accuracy: 0.8460 - val_loss: 0.3931 - val_accuracy: 0.8647
# Epoch 7/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4298 - accuracy: 0.8507 - val_loss: 0.3939 - val_accuracy: 0.8645
# Epoch 8/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4200 - accuracy: 0.8536 - val_loss: 0.4122 - val_accuracy: 0.8543
# Epoch 9/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4106 - accuracy: 0.8572 - val_loss: 0.4020 - val_accuracy: 0.8601
# Epoch 10/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4071 - accuracy: 0.8570 - val_loss: 0.3922 - val_accuracy: 0.8674
# Epoch 11/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3914 - accuracy: 0.8645 - val_loss: 0.3835 - val_accuracy: 0.8641
# Epoch 12/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3866 - accuracy: 0.8640 - val_loss: 0.3783 - val_accuracy: 0.8704
# Epoch 13/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3840 - accuracy: 0.8642 - val_loss: 0.3939 - val_accuracy: 0.8590
# Epoch 14/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3728 - accuracy: 0.8701 - val_loss: 0.3650 - val_accuracy: 0.8736
# Epoch 15/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3700 - accuracy: 0.8698 - val_loss: 0.3780 - val_accuracy: 0.8724
# Epoch 16/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3609 - accuracy: 0.8719 - val_loss: 0.3612 - val_accuracy: 0.8758
# Epoch 17/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3640 - accuracy: 0.8718 - val_loss: 0.3573 - val_accuracy: 0.8763
# Epoch 18/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3575 - accuracy: 0.8736 - val_loss: 0.3692 - val_accuracy: 0.8732
# Epoch 19/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3547 - accuracy: 0.8744 - val_loss: 0.3628 - val_accuracy: 0.8741
# Epoch 20/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3542 - accuracy: 0.8740 - val_loss: 0.3569 - val_accuracy: 0.8761
# Epoch 21/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3466 - accuracy: 0.8778 - val_loss: 0.3727 - val_accuracy: 0.8717
# Epoch 22/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3462 - accuracy: 0.8777 - val_loss: 0.3781 - val_accuracy: 0.8712
# Epoch 23/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3418 - accuracy: 0.8786 - val_loss: 0.3639 - val_accuracy: 0.8730
# Epoch 24/50
# 804/804 [==============================] - 6s 8ms/step - loss: 0.3433 - accuracy: 0.8785 - val_loss: 0.3934 - val_accuracy: 0.8666
# Epoch 25/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3448 - accuracy: 0.8784 - val_loss: 0.3835 - val_accuracy: 0.8691
# Epoch 26/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3362 - accuracy: 0.8806 - val_loss: 0.3810 - val_accuracy: 0.8704
# Epoch 27/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3367 - accuracy: 0.8814 - val_loss: 0.3777 - val_accuracy: 0.8701
# Epoch 00027: early stopping

# %% [markdown]
# ### Avaliação do Modelo

# %%
pred = rede.predict(X_val)

accuracy_score(y_val.argmax(1), pred.argmax(1))
# Out:
# 0.8700505050505051

# %%
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(len(loss))
plt.figure()
plt.plot(epochs, loss, 'bo', label = 'Training loss')
plt.plot(epochs, val_loss, 'b', label = 'Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# # Avaliação do Modelo com os Dados de Teste

# %%
f, ax = plt.subplots(5,5)
f.subplots_adjust(0,0,1.5,1.5)
for i in range(0,5,1):
  for j in range(0,5,1):
    rnd_number = randint(0,len(X_test_raw))
    ax[i,j].imshow(X_test_raw[rnd_number], cmap=plt.cm.binary)
    ax[i,j].set_title(class_names[y_test_raw[rnd_number]])
    ax[i,j].axis('off')

# %% [markdown]
# Pré-processamento dos Dados de Teste

# %%
X_test = X_test_raw / 255
y_test = hot.transform(y_test_raw.reshape(-1,1)).toarray()

# %% [markdown]
# Avaliação do Modelo

# %%
pred = rede.predict(X_test)

accuracy_score(y_test.argmax(1), pred.argmax(1))
# Out:
# 0.8599
