# %% [markdown]
# <a href="https://colab.research.google.com/github/hugoplm/bitcoin-candlestick/blob/main/4_Exercicio_DeepLearning_Paissagem/DL_Paissagem_Modelo3_Hugo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Baixando os Dados

# %%
# !pip install -Uqqq gdown
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   Building wheel for gdown (PEP 517) ... done

# %%
# !gdown 1ORgjWsWnGHdmi7wOZZV64GbQNE4SXkh7
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ORgjWsWnGHdmi7wOZZV64GbQNE4SXkh7
# To: /content/seg_train.zip
# 100% 215M/215M [00:01<00:00, 146MB/s]

# %%
import shutil

# %%
shutil.unpack_archive('seg_train.zip', 'data')

# %% [markdown]
# # Carregando os Dados

# %%
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from random import randint
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
path = "/content/data/seg_train/**/*.jpg"

# %%
X = []
y = []

for files in glob.glob(path, recursive=True):
  image = cv2.imread(files)
  image = cv2.resize(image, (125,125))
  X.append(image)
  y.append(files.split('/')[-2])

# %%
X = np.array(X)
y = np.array(y)
print(X.shape)
print(y.shape)
# Out:
# (14034, 125, 125, 3)
# (14034,)

# %%
f, ax = plt.subplots(5,5)
f.subplots_adjust(0,0,3,3)
for i in range(0,5,1):
  for j in range(0,5,1):
    rnd_number = randint(0,len(X))
    ax[i,j].imshow(X[rnd_number])
    ax[i,j].set_title(y[rnd_number])
    ax[i,j].axis('off')

# %% [markdown]
# # Pré-processamento dos Dados

# %%
X_train, X_val, y_train, y_val = train_test_split(
     X, y, stratify=y, test_size=0.33, random_state=42)

# %%
hot = OneHotEncoder()
y_train = hot.fit_transform(y_train.reshape(-1,1)).toarray()
y_val = hot.transform(y_val.reshape(-1,1)).toarray()

# %%
X_train = X_train / 255
X_val = X_val / 255

# %% [markdown]
# Distribuição das Classes

# %%
import seaborn as sns
sns.countplot(y);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #Modelo Deep Learning

# %% [markdown]
# ## Carregando as Bibliotecas

# %%
from tensorflow.python.keras.layers import Input, Dense, Activation, Dropout, Flatten
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.callbacks import EarlyStopping

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Modelo 3
#
# ```
# # This is formatted as code
# ```
#
#
#
# Maior quantidade de camadas e de neurônios

# %% [markdown]
# ### Definição da Arquitetura

# %%
rede = Sequential()

rede.add(Flatten())
rede.add(Dense(32,  input_dim = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]))
rede.add(Activation('relu'))
rede.add(Dense(64))
rede.add(Activation('relu'))
rede.add(Dense(64))
rede.add(Activation('relu'))
rede.add(Dense(128))
rede.add(Activation('relu'))
rede.add(Dense(128))
rede.add(Activation('relu'))
rede.add(Dense(6))
rede.add(Activation('softmax'))

# %%
es = EarlyStopping(monitor = 'val_loss', 
                   min_delta = 0.001, 
                   patience = 10, 
                   verbose = 1, 
                   mode = 'auto')

# %%
rede.compile(loss = 'categorical_crossentropy', 
              optimizer = 'Adam', 
              metrics=['accuracy'])

# %% [markdown]
# ### Treinamento do Modelo

# %%
hist = rede.fit(X_train, 
                y_train, 
                epochs = 25,
                batch_size=32,
                verbose = 1,
                validation_data = (X_val, y_val),
                callbacks = [es])
# Out:
# Epoch 1/25
# 294/294 [==============================] - 9s 26ms/step - loss: 1.5244 - accuracy: 0.3884 - val_loss: 1.3295 - val_accuracy: 0.4922
# Epoch 2/25
# 294/294 [==============================] - 6s 21ms/step - loss: 1.3144 - accuracy: 0.4853 - val_loss: 1.2293 - val_accuracy: 0.5291
# Epoch 3/25
# 294/294 [==============================] - 6s 21ms/step - loss: 1.2372 - accuracy: 0.5195 - val_loss: 1.2706 - val_accuracy: 0.5028
# Epoch 4/25
# 294/294 [==============================] - 6s 21ms/step - loss: 1.1952 - accuracy: 0.5364 - val_loss: 1.1927 - val_accuracy: 0.5440
# Epoch 5/25
# 294/294 [==============================] - 6s 21ms/step - loss: 1.1697 - accuracy: 0.5434 - val_loss: 1.1997 - val_accuracy: 0.5393
# Epoch 6/25
# 294/294 [==============================] - 6s 21ms/step - loss: 1.1562 - accuracy: 0.5534 - val_loss: 1.2641 - val_accuracy: 0.4903
# Epoch 7/25
# 294/294 [==============================] - 7s 23ms/step - loss: 1.1372 - accuracy: 0.5576 - val_loss: 1.1742 - val_accuracy: 0.5449
# Epoch 8/25
# 294/294 [==============================] - 6s 21ms/step - loss: 1.1106 - accuracy: 0.5665 - val_loss: 1.1965 - val_accuracy: 0.5302
# Epoch 9/25
# 294/294 [==============================] - 6s 21ms/step - loss: 1.1181 - accuracy: 0.5650 - val_loss: 1.1997 - val_accuracy: 0.5315
# Epoch 10/25
# 294/294 [==============================] - 6s 21ms/step - loss: 1.0804 - accuracy: 0.5787 - val_loss: 1.1658 - val_accuracy: 0.5546
# Epoch 11/25
# 294/294 [==============================] - 8s 28ms/step - loss: 1.0854 - accuracy: 0.5848 - val_loss: 1.1800 - val_accuracy: 0.5484
# Epoch 12/25
# 294/294 [==============================] - 7s 24ms/step - loss: 1.0681 - accuracy: 0.5869 - val_loss: 1.1569 - val_accuracy: 0.5579
# Epoch 13/25
# 294/294 [==============================] - 6s 21ms/step - loss: 1.0533 - accuracy: 0.5929 - val_loss: 1.1414 - val_accuracy: 0.5624
# Epoch 14/25
# 294/294 [==============================] - 6s 21ms/step - loss: 1.0474 - accuracy: 0.5918 - val_loss: 1.1558 - val_accuracy: 0.5663
# Epoch 15/25
# 294/294 [==============================] - 6s 21ms/step - loss: 1.0209 - accuracy: 0.6073 - val_loss: 1.1560 - val_accuracy: 0.5646
# Epoch 16/25
# 294/294 [==============================] - 6s 21ms/step - loss: 1.0144 - accuracy: 0.6113 - val_loss: 1.1821 - val_accuracy: 0.5535
# Epoch 17/25
# 294/294 [==============================] - 6s 21ms/step - loss: 0.9897 - accuracy: 0.6159 - val_loss: 1.2273 - val_accuracy: 0.5458
# Epoch 18/25
# 294/294 [==============================] - 7s 23ms/step - loss: 0.9871 - accuracy: 0.6216 - val_loss: 1.1545 - val_accuracy: 0.5710
# Epoch 19/25
# 294/294 [==============================] - 6s 21ms/step - loss: 0.9987 - accuracy: 0.6154 - val_loss: 1.3181 - val_accuracy: 0.5030
# Epoch 20/25
# 294/294 [==============================] - 6s 22ms/step - loss: 0.9835 - accuracy: 0.6208 - val_loss: 1.1832 - val_accuracy: 0.5522
# Epoch 21/25
# 294/294 [==============================] - 6s 21ms/step - loss: 0.9659 - accuracy: 0.6282 - val_loss: 1.4085 - val_accuracy: 0.4845
# Epoch 22/25
# 294/294 [==============================] - 6s 21ms/step - loss: 0.9421 - accuracy: 0.6423 - val_loss: 1.1865 - val_accuracy: 0.5680
# Epoch 23/25
# 294/294 [==============================] - 6s 22ms/step - loss: 0.9358 - accuracy: 0.6388 - val_loss: 1.1876 - val_accuracy: 0.5639
# Epoch 00023: early stopping

# %% [markdown]
# ### Avaliação do Modelo

# %%
pred = rede.predict(X_val)

accuracy_score(y_val.argmax(1), pred.argmax(1))
# Out:
# 0.5639032815198618

# %%
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(len(loss))
plt.figure()
plt.plot(epochs, loss, 'bo', label = 'Training loss')
plt.plot(epochs, val_loss, 'b', label = 'Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
